# %% [markdown]
# **DATA CLEANING AND VISUALIZATION**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('Sleep_Efficiency.csv')
data.head(15)
# Out:
#     ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0    1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1    2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2    3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3    4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4    5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
# 5    6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00             7.5
# 6    7   27  Female  2021-07-21 21:00:00  2021-07-21 03:00:00             6.0
# 7    8   53    Male  2021-08-16 00:30:00  2021-08-16 10:30:00            10.0
# 8    9   41  Female  2021-04-05 02:30:00  2021-04-05 08:30:00             6.0
# 9   10   11  Female  2021-09-16 01:00:00  2021-09-16 10:00:00             9.0
# 10  11   50    Male  2021-02-28 00:30:00  2021-02-28 08:30:00             8.0
# ...

# %%
data.shape
# Out:
# (452, 15)

# %% [markdown]
# We have 452 rows and 15 attributes(columns) in the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      452 non-null    int64
#  1   Age                     452 non-null    int64
#  2   Gender                  452 non-null    object
#  3   Bedtime                 452 non-null    object
#  4   Wakeup time             452 non-null    object
#  5   Sleep duration          452 non-null    float64
#  6   Sleep efficiency        452 non-null    float64
#  7   REM sleep percentage    452 non-null    int64
#  8   Deep sleep percentage   452 non-null    int64
#  9   Light sleep percentage  452 non-null    int64
#  10  Awakenings              432 non-null    float64
#  11  Caffeine consumption    427 non-null    float64
#  12  Alcohol consumption     438 non-null    float64
#  13  Smoking status          452 non-null    object
# ...

# %% [markdown]
# The number of non-null for some attribues is not the same as the number of rows in those attribuest

# %%
data.describe()
# Out:
#                ID         Age  Sleep duration  Sleep efficiency  \
# count  452.000000  452.000000      452.000000        452.000000
# mean   226.500000   40.285398        7.465708          0.788916
# std    130.625419   13.172250        0.866625          0.135237
# min      1.000000    9.000000        5.000000          0.500000
# 25%    113.750000   29.000000        7.000000          0.697500
# 50%    226.500000   40.000000        7.500000          0.820000
# 75%    339.250000   52.000000        8.000000          0.900000
# max    452.000000   69.000000       10.000000          0.990000
#
#        REM sleep percentage  Deep sleep percentage  Light sleep percentage  \
# count            452.000000             452.000000              452.000000
# mean              22.615044              52.823009               24.561947
# std                3.525963              15.654235               15.313665
# min               15.000000              18.000000                7.000000
# ...

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# There are no duplicated rows in the dataset. This is an advantage because we will interprete data clearly and perform accurate analysis.

# %%
data.isnull().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       14
# Smoking status             0
# Exercise frequency         6
# is_duplicate               0
# dtype: int64

# %% [markdown]
# Based on the above data, we can see that "Caffeine consumption" , "Alcohol consumption" and awakenings have missing rows(entries). this affects our analysis going foward. But if the number of missing rows is less than 5% as compared to the number of total in the data set, we can drop them.

# %%
data_cleaned =data.dropna()

# %% [markdown]
# The number of rows that are empty to the total number of rows is significantly small hence they should be dropped .

# %%
data_cleaned.isnull().sum()
# Out:
# ID                        0
# Age                       0
# Gender                    0
# Bedtime                   0
# Wakeup time               0
# Sleep duration            0
# Sleep efficiency          0
# REM sleep percentage      0
# Deep sleep percentage     0
# Light sleep percentage    0
# Awakenings                0
# Caffeine consumption      0
# Alcohol consumption       0
# Smoking status            0
# Exercise frequency        0
# dtype: int64

# %% [markdown]
# The data above shows that the missing entries were removed.

# %%
categorical_cols = data_cleaned.select_dtypes(include=["object", "category"]).columns

for col in categorical_cols:
    unique_values = data[col].unique()
    print(f"Unique values in '{col}': {unique_values}\n")
# Out:
# Unique values in 'Gender': ['Female' 'Male']
#
# Unique values in 'Bedtime': ['2021-03-06 01:00:00' '2021-12-05 02:00:00' '2021-05-25 21:30:00'
#  '2021-11-03 02:30:00' '2021-03-13 01:00:00' '2021-07-01 21:00:00'
#  '2021-07-21 21:00:00' '2021-08-16 00:30:00' '2021-04-05 02:30:00'
#  '2021-09-16 01:00:00' '2021-02-28 00:30:00' '2021-03-10 22:30:00'
#  '2021-08-07 02:30:00' '2021-02-25 01:00:00' '2021-07-03 01:30:00'
#  '2021-12-06 22:00:00' '2021-03-24 01:00:00' '2021-08-27 23:00:00'
#  '2021-07-27 00:00:00' '2021-12-03 00:30:00' '2021-05-02 00:00:00'
#  '2021-06-14 02:30:00' '2021-12-23 22:00:00' '2021-05-21 02:30:00'
#  '2021-09-16 00:00:00' '2021-03-26 00:00:00' '2021-06-18 00:00:00'
#  '2021-12-15 02:30:00' '2021-11-08 21:30:00' '2021-12-25 22:30:00'
#  '2021-08-10 00:00:00' '2021-05-24 00:30:00' '2021-11-28 00:30:00'
#  '2021-07-28 21:30:00' '2021-10-19 01:00:00' '2021-08-06 22:00:00'
#  '2021-09-05 00:00:00' '2021-06-19 00:00:00' '2021-03-26 02:00:00'
# ...

# %% [markdown]
# There are no naming errors in the dataset

# %% [markdown]
# **IDENTIFICATION OF OUTLIERS**

# %%
 Q1 = data_cleaned['Caffeine consumption'].quantile(0.25)
 Q3 = data_cleaned['Caffeine consumption'].quantile(0.75)
 IQR = Q3 - Q1
 outliers = data[(data['Caffeine consumption'] < (Q1 - 1.5 * IQR)) | (data['Caffeine consumption'] > (Q3 + 1.5 * IQR))]

# %%
import matplotlib.pyplot as plt
data_cleaned['Light sleep percentage'].plot(kind='box')
plt.show()

# %% [markdown]
# The diagram above does not depicts outliers.

# %%
import matplotlib.pyplot as plt
data_cleaned['Caffeine consumption'].plot(kind='box')
plt.show()

# %% [markdown]
# With regards to data for "Caffein consumption", we can clearly see tha the diagram shows does not outliers

# %%
 data_cleaned = data_cleaned[(data_cleaned['Caffeine consumption'] >= lower_bound) & (data_cleaned['Caffeine consumption'] <= upper_bound)]

# %%
numeric_cols = data_cleaned.select_dtypes(include=["number"]).columns
plt.figure(figsize=(6, len(numeric_cols) * 4))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(len(numeric_cols), 1, i)
    plt.scatter(data_cleaned.index, data_cleaned[col], alpha=0.6, color="red")
    plt.xlabel("Index")
    plt.ylabel(col)
    plt.title(f"Scatter Plot of {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# These diagrams depict data that does not contain outliers  and it is generally easier to work with and often leads to more reliable and efficient analysis. Without extreme values distorting the distribution, statistical metrics like the mean, standard deviation, and correlation are more representative of the actual dataset. This enhances the accuracy of models, particularly those sensitive to outliers, such as linear regression or clustering algorithms. Additionally, data visualizations become clearer, as plots are not stretched or skewed by extreme points, allowing patterns and trends to be more easily identified. The absence of outliers also reduces the need for complex preprocessing steps.

# %%
data.dtypes
# Out:
# ID                          int64
# Age                         int64
# Gender                     object
# Bedtime                    object
# Wakeup time                object
# Sleep duration            float64
# Sleep efficiency          float64
# REM sleep percentage        int64
# Deep sleep percentage       int64
# Light sleep percentage      int64
# Awakenings                float64
# Caffeine consumption      float64
# Alcohol consumption       float64
# Smoking status             object
# Exercise frequency        float64
# dtype: object

# %% [markdown]
# We can conclude tha the data is clean enough to be used for further analysis and visualization>
